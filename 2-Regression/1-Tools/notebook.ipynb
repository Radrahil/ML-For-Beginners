# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection # type: ignore

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])
print(y)
# Out:
# (20, 3)
# [  5. 162.  60.]
# [[191.  36.  50.]
#  [189.  37.  52.]
#  [193.  38.  58.]
#  [162.  35.  62.]
#  [189.  35.  46.]
#  [182.  36.  56.]
#  [211.  38.  56.]
#  [167.  34.  60.]
#  [176.  31.  74.]
#  [154.  33.  56.]
#  [169.  34.  50.]
#  [166.  33.  52.]
#  [154.  34.  64.]
#  [247.  46.  50.]
#  [193.  36.  46.]
#  [202.  37.  62.]
#  [176.  37.  54.]
#  [157.  32.  52.]
#  [156.  33.  54.]
#  [138.  33.  68.]]

# %%
X = X[:, 1]
X = X.reshape((-1,1))
y = y[:, 1]
y = y.reshape((-1,1))

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.4)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Waistline')
plt.ylabel('Situps')
plt.title('A Graph Plot Showing Waistline to chinups')
plt.show()
